# %% [markdown]
# # La Liga: The Duopoly and Beyond
# **33 seasons of Real-Barca dominance in Spain**
#
# *Eric Schnitger, 2026*
#
# ---
#
# ## Key Findings
#
# - Real + Barca account for ~27 of 33 titles
# - **Atletico's 2014 title** is the only genuine interruption
# - Title points peaked at **100** (2011/12 and 2012/13)

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from _utils import (
   LEAGUES, scrape_league, enrich_dataframe,
   build_league_chart, build_comparison_chart, build_frequency_tables,
)
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
config = LEAGUES["la_liga"]
df = scrape_league("la_liga", cache_dir="../data")
df = enrich_dataframe(df)
print(f"Loaded {len(df)} seasons")
df.tail(10)
# Out:
#   [LL] scraping 1992-2025...
#     1992/93...
# OK
#     1993/94...
# OK
#     1994/95...
# OK
#     1995/96...
# OK
#     1996/97...
# FAIL
#     1997/98...
# OK
#     1998/99...
# OK
#     1999/00...
# FAIL
#     2000/01...
# OK
#     2001/02...
# OK
#     2002/03...
# OK
#     2003/04...
# OK
#     2004/05...
# OK
#     2005/06...
# OK
#     2006/07...
# OK
#     2007/08...
# OK
#     2008/09...
# OK
#     2009/10...
# OK
#     2010/11...
# OK
#     2011/12...
# OK
#     2012/13...
# OK
#     2013/14...
# OK
#     2014/15...
# OK
#     2015/16...
# OK
#     2016/17...
# OK
#     2017/18...
# OK
#     2018/19...
# OK
#     2019/20...
# OK
#     2020/21...
# OK
#     2021/22...
# OK
#     2022/23...
# OK
#     2023/24...
# OK
#     2024/25...
# OK
#   [LL] cached 31 seasons, 2 failures
#     failed: [1996, 1999]
# Loaded 31 seasons
#      Season  Start Year  Num Teams  Matches         Champion  \
# 21  2015/16        2015         20       38        Barcelona
# 22  2016/17        2016         20       38      Real Madrid
# 23  2017/18        2017         20       38        Barcelona
# 24  2018/19        2018         20       38        Barcelona
# 25  2019/20        2019         20       38      Real Madrid
# 26  2020/21        2020         20       38  Atlético Madrid
# 27  2021/22        2021         20       38      Real Madrid
# 28  2022/23        2022         20       38        Barcelona
# 29  2023/24        2023         20       38      Real Madrid
# 30  2024/25        2024         20       38        Barcelona
#
#     Title-Winning Points        2nd Place  2nd Place Points        3rd Place  \
# 21                    91      Real Madrid                90  Atlético Madrid
# 22                    93        Barcelona                90  Atlético Madrid
# 23                    93  Atlético Madrid                79      Real Madrid
# 24                    87  Atlético Madrid                76      Real Madrid
# 25                    87        Barcelona                82  Atlético Madrid
# 26                    86      Real Madrid                84        Barcelona
# 27                    86        Barcelona                73  Atlético Madrid
# 28                    88      Real Madrid                78  Atlético Madrid
# 29                    95        Barcelona                85           Girona
# 30                    88      Real Madrid                84  Atlético Madrid
#
#     3rd Place Points  ... Relegated 2     Relegated 3 Gap  Ratio Title PPG  \
# 21                88  ...      Getafe         Levante  52   2.33     2.395
# 22                78  ...     Osasuna         Granada  58   2.66     2.447
# 23                76  ...  Las Palmas          Málaga  50   2.16     2.447
# 24                68  ...      Huesca  Rayo Vallecano  46   2.12     2.289
# 25                70  ...    Mallorca        Espanyol  50   2.35     2.289
# 26                79  ...  Valladolid           Eibar  50   2.39     2.263
# 27                71  ...     Levante          Alavés  47   2.21     2.263
# 28                77  ...    Espanyol           Elche  47   2.15     2.316
# 29                81  ...     Almería         Granada  57   2.50     2.500
# 30                76  ...  Las Palmas      Valladolid  47   2.15     2.316
#
#    Survival PPG Gap PPG  Title Pts (38-game)  Survival Pts (38-game)  \
# 21        1.026   1.369                 91.0                    39.0
# 22        0.921   1.526                 93.0                    35.0
# 23        1.132   1.315                 93.0                    43.0
# 24        1.079   1.210                 87.0                    41.0
# 25        0.974   1.315                 87.0                    37.0
# 26        0.947   1.316                 86.0                    36.0
# 27        1.026   1.237                 86.0                    39.0
# 28        1.079   1.237                 88.0                    41.0
# 29        1.000   1.500                 95.0                    38.0
# 30        1.079   1.237                 88.0                    41.0
#
#     Gap (38-game)
# 21           52.0
# 22           58.0
# 23           50.0
# 24           46.0
# 25           50.0
# 26           50.0
# 27           47.0
# 28           47.0
# 29           57.0
# 30           47.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Interactive Analysis

# %%
eras = [
   {"label": "Full History (1992-2025)",
    "start": df["Season"].iloc[0], "end": df["Season"].iloc[-1],
    "title": "La Liga: The Duopoly (1992-2025)"},
   {"label": "Classic Era (1992-2004)",
    "start": "1992/93", "end": "2003/04",
    "title": "La Liga: Classic Duopoly"},
   {"label": "Messi/Ronaldo (2004-2018)",
    "start": "2004/05", "end": "2017/18",
    "title": "La Liga: The Messi/Ronaldo Era"},
   {"label": "Post-Legends (2018-2025)",
    "start": "2018/19", "end": df["Season"].iloc[-1],
    "title": "La Liga: Post-Legends"},
]

outliers = [
   {"season": "2011/12", "y": None, "text": "Real 100 pts",   "color": "#FFD54F", "ax": 40,  "ay": -25},
   {"season": "2013/14", "y": None, "text": "Atletico title", "color": "#26C6DA", "ax": -50, "ay": -30},
]

# Resolve missing y-values from actual data
for o in outliers:
   if o.get("y") is None:
       match = df[df["Season"] == o["season"]]
       if not match.empty:
           o["y"] = int(match["Title-Winning Points"].iloc[0])

# %%
fig = build_league_chart(df, config, eras=eras, outliers=outliers)
fig
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="ab960caf-9d94-412d-9f99-3ffb9228c169" class="plotly-graph-div" style="height:1000px; width:1100px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ab960caf-9d94-412d-9f99-3ffb9228c169")) {                    Plotly.newPlot(                        "ab960caf-9d94-412d-9f99-3ffb9228c169",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003e1992\u002f93\u003c\u002fb\u003e\u003cbr\u003e🏆 Barcelona: 58 pts\u003cbr\u003e🥈 Real Madrid: 57 pts\u003cbr\u003e🥉 Deportivo La Coruña: 54 pts\u003cbr\u003e4th: Valencia: 48 pts","\u003cb\u003e1993\u002f94\u003c\u002fb\u003e\u003cbr\u003e🏆 Barcelona: 56 pts\u003cbr\u003e🥈 Deportivo La Coruña: 56 pts\u003cbr\u003e🥉 Zaragoza: 46 pts\u003cbr\u003e4th: Real Madrid: 45 pts","\u003cb\u003e1994\u002f95\u003c\u002fb\u003e\u003cbr\u003e🏆 Real Madrid: 55 pts\u003cbr\u003e🥈 Deportivo La Coruña: 51 pts\u003cbr\u003e🥉 Real Betis: 46 pts\u003cbr\u003e4th: Barcelona: 46 pts","\u003cb\u003e1995\u002f96\u003c\u002fb\u003e\u003cbr\u003e🏆 Atlético Madrid: 87 pts\u003cbr\u003e🥈 Valencia: 83 pts\u003cbr\u003e🥉 Barcelona: 80 pts\u003cbr\u003e4th: Espanyol: 74 pts","\u003cb\u003e1997\u002f98\u003c\u002fb\u003e\u003cbr\u003e🏆 Barcelona: 74 pts\u003cbr\u003e🥈 Athletic Bilbao: 65 pts\u003cbr\u003e🥉 Real Sociedad: 63 pts\u003cbr\u003e4th: Real Madrid: 63 pts","\u003cb\u003e1998\u002f99\u003c\u002fb\u003e\u003cbr\u003e🏆 Barcelona: 79 pts\u003cbr\u
ide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b26c8">
#   <thead>
#     <tr>
#       <th id="T_b26c8_level0_col0" class="col_heading level0 col0" >Club</th>
#       <th id="T_b26c8_level0_col1" class="col_heading level0 col1" >Top 4 Finishes</th>
#       <th id="T_b26c8_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b26c8_row0_col0" class="data row0 col0" >Barcelona</td>
#       <td id="T_b26c8_row0_col1" class="data row0 col1" >30</td>
#       <td id="T_b26c8_row0_col2" class="data row0 col2" >96.8%</td>
#     </tr>
#     <tr>
#       <td id="T_b26c8_row1_col0" class="data row1 col0" >Real Madrid</td>
#       <td id="T_b26c8_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_b26c8_row1_col2" class="data row1 col2" >96.8%</td>
#     </tr>
#     <tr>
#       <td id="T_b26c8_row2_col0" class="data row2 col0" >Atlético Madrid</td>
#       <td id="T_b26c8_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_b26c8_row2_col2" class="data row2 col2" >51.6%</td>
#     </tr>
#     <tr>
#       <td id="T_b26c8_row3_col0" class="data row3 col0" >Valencia</td>
#       <td id="T_b26c8_row3_col1" class="data row3 col1" >13</td>
#       <td id="T_b26c8_row3_col2" class="data row3 col2" >41.9%</td>
#     </tr>
#     <tr>
#       <td id="T_b26c8_row4_col0" class="data row4 col0" >Deportivo La Coruña</td>
#       <td id="T_b26c8_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_b26c8_row4_col2" class="data row4 col2" >22.6%</td>
#     </tr>
#     <tr>
#       <td id="T_b26c8_row5_col0" class="data row5 col0" >Sevilla</td>
#       <td id="T_b26c8_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_b26c8_row5_col2" class="data row5 col2" >22.6%</td>
#     </tr>
#     <tr>
#       <td id="T_b26c8_row6_col0" class="data row6 col0" >Real Sociedad</td>
#       <td id="T_b26c8_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_b26c8_row6_col2" class="data row6 col2" >12.9%</td>
#     </tr>
#     <tr>
#       <td id="T_b26c8_row7_col0" class="data row7 col0" >Villarreal</td>
#       <td id="T_b26c8_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_b26c8_row7_col2" class="data row7 col2" >12.9%</td>
#     </tr>
#     <tr>
#       <td id="T_b26c8_row8_col0" class="data row8 col0" >Athletic Bilbao</td>
#       <td id="T_b26c8_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_b26c8_row8_col2" class="data row8 col2" >9.7%</td>
#     </tr>
#     <tr>
#       <td id="T_b26c8_row9_col0" class="data row9 col0" >Real Betis</td>
#       <td id="T_b26c8_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_b26c8_row9_col2" class="data row9 col2" >6.5%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Relegated Clubs

# %%
relegated.head(10).style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8be12">
#   <thead>
#     <tr>
#       <th id="T_8be12_level0_col0" class="col_heading level0 col0" >Club</th>
#       <th id="T_8be12_level0_col1" class="col_heading level0 col1" >Times Relegated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8be12_row0_col0" class="data row0 col0" >Valladolid</td>
#       <td id="T_8be12_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_8be12_row1_col0" class="data row1 col0" >Sporting Gijón</td>
#       <td id="T_8be12_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_8be12_row2_col0" class="data row2 col0" >Levante</td>
#       <td id="T_8be12_row2_col1" class="data row2 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_8be12_row3_col0" class="data row3 col0" >Las Palmas</td>
#       <td id="T_8be12_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_8be12_row4_col0" class="data row4 col0" >Alavés</td>
#       <td id="T_8be12_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_8be12_row5_col0" class="data row5 col0" >Zaragoza</td>
#       <td id="T_8be12_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_8be12_row6_col0" class="data row6 col0" >Deportivo La Coruña</td>
#       <td id="T_8be12_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_8be12_row7_col0" class="data row7 col0" >Osasuna</td>
#       <td id="T_8be12_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_8be12_row8_col0" class="data row8 col0" >Rayo Vallecano</td>
#       <td id="T_8be12_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_8be12_row9_col0" class="data row9 col0" >Granada</td>
#       <td id="T_8be12_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#   </tbody>
# </table>
